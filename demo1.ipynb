# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Rahul Paul\OneDrive\Desktop\dataset\dataset 1.csv')
print(df)
# Out:
#       Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0      22    Male  Electronics And Communication            1     8       1
# 1      21  Female               Computer Science            0     7       1
# 2      22  Female         Information Technology            1     6       0
# 3      21    Male         Information Technology            0     8       0
# 4      22    Male                     Mechanical            0     8       1
# ...   ...     ...                            ...          ...   ...     ...
# 2961   23    Male         Information Technology            0     7       0
# 2962   23    Male                     Mechanical            1     7       1
# 2963   22    Male         Information Technology            1     7       0
# 2964   22    Male               Computer Science            1     7       0
# 2965   23    Male                          Civil            0     8       0
#
#       HistoryOfBacklogs  PlacedOrNot
# ...

# %%
df.head()
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22    Male  Electronics And Communication            1     8       1
# 1   21  Female               Computer Science            0     7       1
# 2   22  Female         Information Technology            1     6       0
# 3   21    Male         Information Technology            0     8       0
# 4   22    Male                     Mechanical            0     8       1
#
#    HistoryOfBacklogs  PlacedOrNot
# 0                  1            1
# 1                  1            1
# 2                  0            1
# 3                  1            1
# 4                  0            1

# %%
sns.barplot(x="CGPA",y="PlacedOrNot",data=df)
plt.savefig("plot 1.png")
plt.show()

# %%
sns.barplot(x="Internships",y="PlacedOrNot",data=df,hue="Gender")
plt.savefig("plot 2.png")
plt.show()

# %%
sns.histplot(df["Age"])
plt.savefig("plot 3.png")
plt.show()

# %%
sns.countplot(x="PlacedOrNot",data=df,hue="Gender")
plt.savefig("plot 4.png")
plt.show()

# %%
sns.countplot(x="PlacedOrNot",data=df,hue="CGPA")
plt.savefig("plot 5.png")
plt.show()

# %%
sns.pairplot(df,vars=["CGPA","PlacedOrNot"])
plt.savefig("plot 6.png")
plt.show()

# %%
sns.countplot(x="HistoryOfBacklogs",data=df,hue="Gender")
plt.savefig("plot 7.png")
plt.show()

# %%
sns.barplot(x="HistoryOfBacklogs",y="PlacedOrNot",data=df,hue="Gender")
plt.savefig("plot 8.png")
plt.show()

# %%
sns.barplot(x="Internships",y="PlacedOrNot",data=df,hue="CGPA")
plt.savefig("plot 9.png")
plt.show()

# %%
sns.barplot(x="CGPA",y="PlacedOrNot",data=df,hue="Internships")
plt.savefig("plot 10.png")
plt.show()

# %%
sns.barplot(x="Hostel",y="PlacedOrNot",data=df,hue="CGPA")
plt.savefig("plot 11.png")
plt.show()

# %%
sns.barplot(x="Stream",y="PlacedOrNot",data=df,hue="Internships")
plt.savefig("plot 12.png")
plt.show()

# %%
sns.barplot(x="Age",y="PlacedOrNot",data=df,hue="Internships")
plt.savefig("plot 13.png")
plt.show()

# %%
sns.scatterplot(x="CGPA",y="PlacedOrNot",data=df,hue="Gender")
plt.savefig("plot 14.png")
plt.show()

# %%
sns.lineplot(x="CGPA",y="PlacedOrNot",data=df,hue="Gender")
plt.savefig("plot 15.png")
plt.show()

# %%
sns.lineplot(x="Stream",y="PlacedOrNot",data=df,hue="Gender")
plt.savefig("plot 16.png")
plt.show()

# %%
sns.lineplot(x="CGPA",y="PlacedOrNot",data=df,hue="Internships")
plt.savefig("plot 17.png")
plt.show()

# %%
sns.lineplot(x="Internships",y="PlacedOrNot",data=df,hue="CGPA")
plt.savefig("plot 18.png")
plt.show()

# %%
df.shape
# Out:
# (2966, 8)

# %%
df['Gender'].replace({'Male':0,'Female':1},inplace=True)

# %%
df.head()
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22       0  Electronics And Communication            1     8       1
# 1   21       1               Computer Science            0     7       1
# 2   22       1         Information Technology            1     6       0
# 3   21       0         Information Technology            0     8       0
# 4   22       0                     Mechanical            0     8       1
#
#    HistoryOfBacklogs  PlacedOrNot
# 0                  1            1
# 1                  1            1
# 2                  0            1
# 3                  1            1
# 4                  0            1

# %%
df['Stream'].unique()
# Out:
# array(['Electronics And Communication', 'Computer Science',
#        'Information Technology', 'Mechanical', 'Electrical', 'Civil'],
#       dtype=object)

# %%
df['Stream'].replace({'Electronics And Communication':0,'Computer Science':1,'Information Technology':2,'Mechanical':3,
                     'Electrical':4,'Civil':5},inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Stream  Internships  CGPA  Hostel  HistoryOfBacklogs  \
# 0   22       0       0            1     8       1                  1
# 1   21       1       1            0     7       1                  1
# 2   22       1       2            1     6       0                  0
# 3   21       0       2            0     8       0                  1
# 4   22       0       3            0     8       1                  0
#
#    PlacedOrNot
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
df.isnull().sum()
# Out:
# Age                  0
# Gender               0
# Stream               0
# Internships          0
# CGPA                 0
# Hostel               0
# HistoryOfBacklogs    0
# PlacedOrNot          0
# dtype: int64

# %%
Y = df['PlacedOrNot']
X = df.drop(['PlacedOrNot'],axis=1)

# %%
X
# Out:
#       Age  Gender  Stream  Internships  CGPA  Hostel  HistoryOfBacklogs
# 0      22       0       0            1     8       1                  1
# 1      21       1       1            0     7       1                  1
# 2      22       1       2            1     6       0                  0
# 3      21       0       2            0     8       0                  1
# 4      22       0       3            0     8       1                  0
# ...   ...     ...     ...          ...   ...     ...                ...
# 2961   23       0       2            0     7       0                  0
# 2962   23       0       3            1     7       1                  0
# 2963   22       0       2            1     7       0                  0
# 2964   22       0       1            1     7       0                  0
# 2965   23       0       5            0     8       0                  0
#
# [2966 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
#from sklearn.ensemble import GradientBoostingClassifier

# %%
lr = LogisticRegression()
lr.fit(X_train,Y_train)

svm = svm.SVC()
svm.fit(X_train,Y_train)

knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)

dt=DecisionTreeClassifier()
dt.fit(X_train,Y_train)

rf=RandomForestClassifier()
rf.fit(X_train,Y_train)

#gb=GradientBoostingClassifier()
#gb.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = svm.predict(X_test)
y_pred3 = knn.predict(X_test)
y_pred4 = dt.predict(X_test)
y_pred5 = rf.predict(X_test)
#y_pred6 = gb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

score1=accuracy_score(Y_test,y_pred1)
score2=accuracy_score(Y_test,y_pred2)
score3=accuracy_score(Y_test,y_pred3)
score4=accuracy_score(Y_test,y_pred4)
score5=accuracy_score(Y_test,y_pred5)
#score6=accuracy_score(Y_test,y_pred6)

# %%
print(score1,score2,score3,score4,score5)
# Out:
# 0.7811447811447811 0.7895622895622896 0.8653198653198653 0.8653198653198653 0.8686868686868687

# %%
final_data = pd.DataFrame({'Models':['LR','SVC','KNN','DT','RF'],
            'ACC':[score1*100,
                  score2*100,
                  score3*100,
                  score4*100,
                  score5*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  78.114478
# 1    SVC  78.956229
# 2    KNN  86.531987
# 3     DT  86.531987
# 4     RF  86.868687

# %%
sns.barplot(x="Models",y="ACC",data=final_data)
plt.savefig("plot 19.png")
plt.show()

# %%
#from sklearn.linear_model import LogisticRegression  
#classifier = LogisticRegression()
#classifier.fit(X_train,Y_train)

# %%
#from sklearn.metrics import accuracy_score
#Y_pred = classifier.predict(X_test)
#print("Accuracy: ",accuracy_score(Y_test,Y_pred))

# %%
#from sklearn.ensemble import RandomForestClassifier  
  
#classifier = RandomForestClassifier(max_depth=10, random_state=0)  
#classifier.fit(X_train,Y_train)  
#Y_pred = classifier.predict(X_test)
#print("Accuracy: ",accuracy_score(Y_test,Y_pred))

# %%
#import pickle
#pickle.dump(classifier,open('model.pkl','wb'))
